# %% [markdown]
# # Predicting with the Trained Neural Network
# This notebook allows you to make predictions on new/unseen football data using the trained 1-layer neural network. It loads new data, applies preprocessing (PCA), loads the trained model, and generates predictions and probabilities.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
import joblib

# %% [markdown]
# ## 1. Load New Data
# Upload or specify the path to your new data file (CSV or similar). Ensure it matches the expected format.

# %%
# Example: Load new data
new_data = pd.read_csv('path/to/new_data.csv')  # Update path as needed
new_data.head()

# %% [markdown]
# ## 2. Preprocessing
# Apply the same preprocessing steps as used in training: PCA transformation and scaling (if applicable). Here we load the PCA model saved in the dimension reduction step.

# %%
# Load fitted PCA model
pca = joblib.load('../c_Dimension_Reduction/Positition_group_PCA_model.pkl')

# If a scaler was used prior to PCA in your pipeline, load it here as well:
# scaler = joblib.load('../b_Data_Models/scaler_model.pkl')

# Define features used in scaling/PCA (drop metadata and non-numeric columns)
cols_to_drop = [
    'home_club_name', 'away_club_name', 'date', 'season', 'round', 
    'home_club_formation', 'away_club_formation'
]
X_new = new_row_df.drop(columns=cols_to_drop, errors='ignore')

# Identify missing scaling step if applicable
# X_new = scaler.transform(X_new)

# Apply PCA transformation
X_new_pca = pca.transform(X_new)

print("Applied PCA. Transformed shape:", X_new_pca.shape)

# %% [markdown]
# ## 3. Load Trained Neural Network Model
# Load the trained NN model (.h5 file).

# %%
# Load trained model
model = keras.models.load_model('../f_Trained_Models/Neural Network_best_model.h5')

# %% [markdown]
# ## 4. Make Predictions
# Generate class predictions and probabilities for the new data.

# %%
# Predict probabilities and classes using PCA components
proba = model.predict(X_new_pca)
pred_classes = np.argmax(proba, axis=1)

# Map numeric classes to labels if needed
class_labels = ['Home', 'Draw', 'Away']  # Update if different
pred_labels = [class_labels[i] for i in pred_classes]

# %% [markdown]
# ## 5. Save and Display Results
# Save predictions and probabilities to CSV. Display a sample.

# %%
# Save predictions
output_df = new_row_df.copy()
output_df['predicted_NN'] = pred_labels
output_df[['proba_Home', 'proba_Draw', 'proba_Away']] = proba

# Display result
output_df[['home_club_name', 'away_club_name', 'predicted_NN', 'proba_Home', 'proba_Draw', 'proba_Away']]

# %% [markdown]
# ---
# **Notebook complete.** You can now use this workflow to make predictions on any new football data using your trained neural network.

# %% [markdown]
# ## 0. Generate a New Prediction Row by User Input
# This cell allows you to manually input values for a new match and generate a prediction row with all required features.

# %%
# Manually input values for a new match
import pandas as pd

# Example: Define the required columns (update as needed based on your feature list)
feature_columns = [
    'home_club_name', 'away_club_name', 'date', 'season', 'round', 'attendance',
    'home_club_formation', 'away_club_formation',
    'home_club_position_before_game', 'away_club_position_before_game',
    'home_form', 'away_form',
    'home_market_value_Goalkeeper', 'away_market_value_Goalkeeper',
    'home_rating_overall_Goalkeeper', 'away_rating_overall_Goalkeeper',
    'home_rating_goalkeeping_diving_Goalkeeper', 'away_rating_goalkeeping_diving_Goalkeeper',
    'home_rating_goalkeeping_handling_Goalkeeper', 'away_rating_goalkeeping_handling_Goalkeeper',
    'home_rating_goalkeeping_kicking_Goalkeeper', 'away_rating_goalkeeping_kicking_Goalkeeper',
    'home_rating_goalkeeping_positioning_Goalkeeper', 'away_rating_goalkeeping_positioning_Goalkeeper',
    'home_rating_goalkeeping_reflexes_Goalkeeper', 'away_rating_goalkeeping_reflexes_Goalkeeper',
    'home_rating_goalkeeping_speed_Goalkeeper', 'away_rating_goalkeeping_speed_Goalkeeper',
    'home_market_value_Defenders', 'away_market_value_Defenders',
    'home_rating_overall_Defenders', 'away_rating_overall_Defenders',
    'home_rating_pace_Defenders', 'away_rating_pace_Defenders',
    'home_rating_shooting_Defenders', 'away_rating_shooting_Defenders',
    'home_rating_passing_Defenders', 'away_rating_passing_Defenders',
    'home_rating_dribbling_Defenders', 'away_rating_dribbling_Defenders',
    'home_rating_defending_Defenders', 'away_rating_defending_Defenders',
    'home_rating_physic_Defenders', 'away_rating_physic_Defenders',
    'home_market_value_Midfielders', 'away_market_value_Midfielders',
    'home_rating_overall_Midfielders', 'away_rating_overall_Midfielders',
    'home_rating_pace_Midfielders', 'away_rating_pace_Midfielders',
    'home_rating_shooting_Midfielders', 'away_rating_shooting_Midfielders',
    'home_rating_passing_Midfielders', 'away_rating_passing_Midfielders',
    'home_rating_dribbling_Midfielders', 'away_rating_dribbling_Midfielders',
    'home_rating_defending_Midfielders', 'away_rating_defending_Midfielders',
    'home_rating_physic_Midfielders', 'away_rating_physic_Midfielders',
    'home_market_value_Attackers', 'away_market_value_Attackers',
    'home_rating_overall_Attackers', 'away_rating_overall_Attackers',
    'home_rating_pace_Attackers', 'away_rating_pace_Attackers',
    'home_rating_shooting_Attackers', 'away_rating_shooting_Attackers',
    'home_rating_passing_Attackers', 'away_rating_passing_Attackers',
    'home_rating_dribbling_Attackers', 'away_rating_dribbling_Attackers',
    'home_rating_defending_Attackers', 'away_rating_defending_Attackers',
    'home_rating_physic_Attackers', 'away_rating_physic_Attackers'
]

# Prompt user for input (for demonstration, use a dictionary or input() for each value)
# Example: Use a dictionary for quick entry
user_input = {
    'home_club_name': 'Bayern Munich',
    'away_club_name': 'Dortmund',
    'date': '2026-03-10',
    'season': 2026,
    'round': '25. Matchday',
    'attendance': 75000,
    'home_club_formation': '4-3-3 Attacking',
    'away_club_formation': '4-2-3-1',
    'home_club_position_before_game': 1,
    'away_club_position_before_game': 2,
    'home_form': 4,
    'away_form': 3,
    'home_market_value_Goalkeeper': 20000000,
    'away_market_value_Goalkeeper': 18000000,
    'home_rating_overall_Goalkeeper': 90,
    'away_rating_overall_Goalkeeper': 88,
    'home_rating_goalkeeping_diving_Goalkeeper': 92,
    'away_rating_goalkeeping_diving_Goalkeeper': 89,
    'home_rating_goalkeeping_handling_Goalkeeper': 91,
    'away_rating_goalkeeping_handling_Goalkeeper': 87,
    'home_rating_goalkeeping_kicking_Goalkeeper': 93,
    'away_rating_goalkeeping_kicking_Goalkeeper': 86,
    'home_rating_goalkeeping_positioning_Goalkeeper': 94,
    'away_rating_goalkeeping_positioning_Goalkeeper': 85,
    'home_rating_goalkeeping_reflexes_Goalkeeper': 95,
    'away_rating_goalkeeping_reflexes_Goalkeeper': 90,
    'home_rating_goalkeeping_speed_Goalkeeper': 80,
    'away_rating_goalkeeping_speed_Goalkeeper': 78,
    'home_market_value_Defenders': 50000000,
    'away_market_value_Defenders': 45000000,
    'home_rating_overall_Defenders': 88,
    'away_rating_overall_Defenders': 86,
    'home_rating_pace_Defenders': 85,
    'away_rating_pace_Defenders': 83,
    'home_rating_shooting_Defenders': 80,
    'away_rating_shooting_Defenders': 78,
    'home_rating_passing_Defenders': 87,
    'away_rating_passing_Defenders': 85,
    'home_rating_dribbling_Defenders': 84,
    'away_rating_dribbling_Defenders': 82,
    'home_rating_defending_Defenders': 90,
    'away_rating_defending_Defenders': 88,
    'home_rating_physic_Defenders': 89,
    'away_rating_physic_Defenders': 87,
    'home_market_value_Midfielders': 60000000,
    'away_market_value_Midfielders': 55000000,
    'home_rating_overall_Midfielders': 91,
    'away_rating_overall_Midfielders': 89,
    'home_rating_pace_Midfielders': 88,
    'away_rating_pace_Midfielders': 86,
    'home_rating_shooting_Midfielders': 85,
    'away_rating_shooting_Midfielders': 83,
    'home_rating_passing_Midfielders': 90,
    'away_rating_passing_Midfielders': 88,
    'home_rating_dribbling_Midfielders': 89,
    'away_rating_dribbling_Midfielders': 87,
    'home_rating_defending_Midfielders': 86,
    'away_rating_defending_Midfielders': 84,
    'home_rating_physic_Midfielders': 87,
    'away_rating_physic_Midfielders': 85,
    'home_market_value_Attackers': 70000000,
    'away_market_value_Attackers': 65000000,
    'home_rating_overall_Attackers': 93,
    'away_rating_overall_Attackers': 91,
    'home_rating_pace_Attackers': 92,
    'away_rating_pace_Attackers': 90,
    'home_rating_shooting_Attackers': 95,
    'away_rating_shooting_Attackers': 93,
    'home_rating_passing_Attackers': 94,
    'away_rating_passing_Attackers': 92,
    'home_rating_dribbling_Attackers': 96,
    'away_rating_dribbling_Attackers': 94,
    'home_rating_defending_Attackers': 85,
    'away_rating_defending_Attackers': 83,
    'home_rating_physic_Attackers': 90,
    'away_rating_physic_Attackers': 88
}

# Create a DataFrame for the new prediction row
new_row_df = pd.DataFrame([user_input], columns=feature_columns)
new_row_df.head()
