# %%
# get the unique team names from data/lineups_values_ratings_games.csv (column name: Home Team)
import pandas as pd
df = pd.read_csv("data/data_pca.csv")
teams = df["Home Team"].unique()
print(teams)
# Out:
# ['FC Girondins Bordeaux' 'Football Club de Nantes'
#  'Olympique de Marseille' 'Football Club de Metz'
#  'Football Club Lorient-Bretagne Sud' 'Toulouse Football Club'
#  'Paris Saint-Germain Football Club'
#  'Association sportive de Monaco Football Club'
#  'Lille Olympique Sporting Club' 'Racing Club de Lens'
#  'Stade Rennais Football Club' 'Stade Reims' 'SM Caen'
#  'Thonon Évian Grand Genève FC' 'Olympique Lyonnais' 'Montpellier HSC'
#  'EA Guingamp' 'SC Bastia' "Olympique Gymnaste Club Nice Côte d'Azur"
#  'AS Saint-Étienne' 'Elche Club de Fútbol S.A.D.'
#  '1. Fußball- und Sportverein Mainz 05' 'Hull City'
#  'Levante Unión Deportiva S.A.D.' 'Athletic Club Bilbao'
#  'Villarreal Club de Fútbol S.A.D.' 'Club Atlético de Madrid S.A.D.'
#  'Liverpool Football Club' 'Arsenal Football Club'
#  'Crystal Palace Football Club' 'Southampton FC'
#  'Verein für Leibesübungen Wolfsburg' 'FC Schalke 04'
#  'Sport-Club Freiburg' 'Verein für Bewegungsspiele Stuttgart 1893'
# ...

# %%
df2 = pd.read_csv("matchhistory_data/match_statistics.csv")
teams2 = df2["HomeTeam"].unique()
print(teams2)
# Out:
# ['Arsenal' 'Leicester' 'Man United' 'QPR' 'Stoke' 'West Brom' 'West Ham'
#  'Liverpool' 'Newcastle' 'Burnley' 'Aston Villa' 'Chelsea'
#  'Crystal Palace' 'Everton' 'Southampton' 'Swansea' 'Hull' 'Sunderland'
#  'Tottenham' 'Man City' nan 'Bournemouth' 'Norwich' 'Watford'
#  'Middlesbrough' 'Brighton' 'Huddersfield' 'Fulham' 'Wolves' 'Cardiff'
#  'Sheffield United' 'Leeds' 'Brentford' "Nott'm Forest" 'Luton' 'Ipswich'
#  'Bayern Munich' 'Dortmund' 'Ein Frankfurt' 'FC Koln' 'Hannover' 'Hertha'
#  'Hoffenheim' "M'gladbach" 'Paderborn' 'Augsburg' 'Hamburg' 'Leverkusen'
#  'Schalke 04' 'Stuttgart' 'Werder Bremen' 'Wolfsburg' 'Freiburg' 'Mainz'
#  'Darmstadt' 'Ingolstadt' 'RB Leipzig' 'Fortuna Dusseldorf' 'Nurnberg'
#  'Union Berlin' 'Bielefeld' 'Bochum' 'Greuther Furth' 'Heidenheim'
#  'St Pauli' 'Holstein Kiel' 'Chievo' 'Roma' 'Atalanta' 'Cesena' 'Genoa'
#  'Milan' 'Palermo' 'Sassuolo' 'Torino' 'Udinese' 'Empoli' 'Juventus'
# ...

# %%
import pandas as pd
df3 = pd.read_csv("../data/big5_xg_clean.csv")

teams3 = df3["home_team"].unique()
print(teams3)
# Out:
# ['Reims' 'Evian Thonon Gaillard' 'Guingamp' 'Lille' 'Montpellier' 'Nantes'
#  'Nice' 'SC Bastia' 'Lyon' 'Monaco' 'Caen' 'Lens' 'Lorient' 'Metz'
#  'Paris Saint Germain' 'Rennes' 'Toulouse' 'Arsenal' 'Leicester'
#  'Manchester United' 'Queens Park Rangers' 'Stoke' 'West Bromwich Albion'
#  'West Ham' 'Bordeaux' 'Marseille' 'Saint-Etienne' 'Liverpool'
#  'Newcastle United' 'Burnley' 'Bayern Munich' 'Borussia Dortmund'
#  'Eintracht Frankfurt' 'FC Cologne' 'Hannover 96' 'Hertha Berlin'
#  'Hoffenheim' 'Almeria' 'Granada' 'Malaga' 'Sevilla' 'Aston Villa'
#  'Chelsea' 'Crystal Palace' 'Everton' 'Southampton' 'Swansea'
#  'Borussia M.Gladbach' 'Paderborn' 'Barcelona' 'Celta Vigo' 'Eibar'
#  'Levante' 'Hull' 'Sunderland' 'Tottenham' 'Rayo Vallecano' 'Real Madrid'
#  'Manchester City' 'Augsburg' 'Getafe' 'Valencia' 'Bayer Leverkusen'
#  'Hamburger SV' 'Schalke 04' 'VfB Stuttgart' 'Werder Bremen' 'Wolfsburg'
#  'Athletic Club' 'Atletico Madrid' 'Cordoba' 'Espanyol' 'Chievo' 'Roma'
# ...
